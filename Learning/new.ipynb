# %%
# Write a python program to count the frequency of any specific word (in your domain) in the paragraph.
paragraph="This computer science project involves developing a user-centric application to connect urban residents with skilled labor workers like electricians, plumbers, and gardeners. The application's robust database incorporates ten distinct entities, each possessing a minimum of ten attributes. These entities include Users/Clients, Skilled Labor Workers, Services/Job Listings, Reviews and Ratings, Payment Transactions, Worker Availability Schedule, Client Preferences, Service Categories, Location/City Information, and Notifications and Alerts. To ensure efficient data management, the project utilizes various data types,IDs-integer, names-string , descriptions-string, timestamps-dates, hourlyRates-float, statusIndicator-boolean. The diverse data types enhance the application's functionality and enrich users' experience while seeking skilled labor services in major cities."
specificWord= input("Enter Word to find its frequency")
paragraph= paragraph.lower()
specificWord=specificWord.lower()
words = paragraph.split()
frequency = words.count(specificWord)
print("The word  '",specificWord,"'  Occurs ",frequency,"times")
# Out:
# The word  ' the '  Occurs  4 times

# %%
# Write a python program to count the number of alphabets, numeric and other special symbols in the paragraph.
paragraph="This 12345 computer science project involves developing a user-centric application to connect urban residents with skilled labor workers like electricians, plumbers, and gardeners. The application's robust database incorporates ten distinct entities, each possessing a minimum of ten attributes. These entities include Users/Clients, Skilled Labor Workers, Services/Job Listings, Reviews and Ratings, Payment Transactions, Worker Availability Schedule, Client Preferences, Service Categories, Location/City Information, and Notifications and Alerts. To ensure efficient data management, the project utilizes various data types,IDs-integer, names-string , descriptions-string, timestamps-date, hourlyRates-float, statusIndicator-boolean. The diverse data types enhance the application's functionality and enrich users' experience while seeking skilled labor services in major cities."
alphabetCount=0
digitCount=0
specialCharCount=0
spaceCount=0
for charecter in paragraph:
    if(charecter.isdigit()):
        digitCount+=1
    elif(charecter.isalpha()):
        alphabetCount+=1
    elif(charecter.isspace()):
        spaceCount+=1
    else:
        specialCharCount+=1

print("Alphabets          : ",alphabetCount)
print("Digits             : ",digitCount)
print("Special Charecters : ",specialCharCount)
print("Spaces             : ",spaceCount)
# Out:
# Alphabets          :  739
# Digits             :  5
# Special Charecters :  37
# Spaces             :  101

# %%
# Write a python program to display all the datatypes of selected specific elements in the paragraph. (For example:– name - string, reg.no - int, marks - float, etc.)
paragraph="This computer science project involves developing a user-centric application to connect urban residents with skilled labor workers like electricians, plumbers, and gardeners. The application's robust database incorporates ten distinct entities, each possessing a minimum of ten attributes. These entities include Users/Clients, Skilled Labor Workers, Services/Job Listings, Reviews and Ratings, Payment Transactions, Worker Availability Schedule, Client Preferences, Service Categories, Location/City Information, and Notifications and Alerts. To ensure efficient data management, the project utilizes various data types,IDs-integer, names-string , descriptions-string, timestamps-date, hourlyRates-float, statusIndicator-boolean. The diverse data types enhance the application's functionality and enrich users' experience while seeking skilled labor services in major cities."
import re
def datatypeExtractor(paragraph):
    dataSet={}
    regexPattern = r"([A-Za-z0-9_]+)\s*-\s*(integer|float|boolean|string|date)"
    matches = re.findall(regexPattern, paragraph)

    for elementName, dataType in matches:
        dataSet[elementName] = dataType
    return dataSet

dataTypesSet = datatypeExtractor(paragraph)
for node,dtype in dataTypesSet.items():
    print(f"{node}-->{dtype}")
# Out:
# IDs-->integer
# names-->string
# descriptions-->string
# hourlyRates-->float
# statusIndicator-->boolean

# %%
# Create a Set with elements that consists of various data types (int, float, string, Boolean, etc. from your domain) and perform the functions pop(), clear(), discard() and del. Write the insights as docstring.
def setOperation():
    initialSet={ 45 , True , 59.6 , "Sigma" , (9,5,6,7)}
    print("Initial Set is : ",initialSet)

    poppedElement= initialSet.pop()
    print("Popped Element : ",poppedElement)
    print("Set after Element Pop : ",initialSet)

    discardElement=45
    initialSet.discard(discardElement)
    print("Set after Discarding Element : ",initialSet)

    initialSet.clear()
    print("Set after Clearing : ",initialSet)

    initialSet={ 45 , True , 59.6 , "Sigma" , (9,5,6,7)}

    del initialSet
    
    try:
        print("Set After deletion",initialSet)
    except:
        print("Element Cant Be Displayed As it was deleted")  

setOperation()

"""" 
>>Sets are collection of unordered Elements.
>>The elements popped or discarded can change on each execution as set is unordered
>>Sets can contain diffrent kinds of data within it 
>>The pop() function  removes an arbitrary value from the set and the
  popped element is returned hence it cannot be predicted
>>The discard() function removes a particular element from the Set which can be decided.If the 
  told element does not exist in the list it does not raise an error
>>The clear() function makes the set empty or clears all the elements in the set.
>>The del keyword removes the set variable from memory making it inaccessable.if tried to access 
  it would raise a KeyError
"""
# Out:
# Initial Set is :  {True, 'Sigma', (9, 5, 6, 7), 59.6, 45}
# Popped Element :  True
# Set after Element Pop :  {'Sigma', (9, 5, 6, 7), 59.6, 45}
# Set after Discarding Element :  {'Sigma', (9, 5, 6, 7), 59.6}
# Set after Clearing :  set()
# Element Cant Be Displayed As it was deleted

# %%
# Update the Set with minimum 5 string attributes of your domain and arrange the Set in descending order.

"""" 
The Attributes used here are :
ClientName
WorkerId
Location
Rating
MaxAmountPerHour
"""

domainAttributes={"clientName","workerId","location","rating","maxAmountPerHour"}
print("Initial Set : ",domainAttributes)
sortedSet= sorted(domainAttributes,reverse=True)
print("Sorted Set : ",sortedSet)
# Out:
# Initial Set :  {'WorkerId', 'ClientName', 'Location', 'Rating', 'MaxAmountPerHour'}
# Sorted Set :  ['WorkerId', 'Rating', 'MaxAmountPerHour', 'Location', 'ClientName']

# %%
# Create a Tuple and Execute the packing and unpacking operations of tuples using the attributes of your domain.
pattr1="clientId"
pattr2="workerName"
pattr3="workerAvailablity"
pattr4="clientAge"
pattr5="expectedDuration"
attributeTuple=tuple([pattr1,pattr2,pattr3,pattr4,pattr5])
attr1,attr2,*attr3,attr4=attributeTuple
print("The initial tuple : ",attributeTuple)
print("Attribute 1 : ",attr1)
print("Attribute 2 : ",attr2)
print("Attributes 3 : ",attr3)
print("Attribute 4 : ",attr4)
# Out:
# The initial tuple :  ('clientId', 'workerName', 'workerAvailablity', 'clientAge', 'expectedDuration')
# Attribute 1 :  clientId
# Attribute 2 :  workerName
# Attributes 3 :  ['workerAvailablity', 'clientAge']
# Attribute 4 :  expectedDuration

# %%
# Enter your domain name as characters and count any number of characters and print 
# the count (for example – (‘p’,’r’,’o’,’g’,’r’,’a’,’m’) count of ‘r’ = 2

def alphabetCounter(domainName):
    letterSet={}
    for letter in domainName:
        if letter.isalpha():
            lowerLetter=letter.lower()
            letterSet[lowerLetter]=letterSet.get(lowerLetter,0)+1
    return letterSet
# domainName=('L','a','b','o','r','M','a','n','a','g','e','m','e','n','t')
domainName=input("Enter the domain Name")

letterSet= alphabetCounter(domainName)

print(domainName)
print("Letter counts")
for letter,lCount in letterSet.items():
    print(letter," : ",lCount)
# Out:
# labor Management
# Letter counts
# l  :  1
# a  :  3
# b  :  1
# o  :  1
# r  :  1
# m  :  2
# n  :  2
# g  :  1
# e  :  2
# t  :  1

# %%
# Enter your domain name, execute all the slicing possibilities and also negative indexing.
domainName= input("Enter your Domain Name")
stringLength=len(domainName)
# print(stringLength)

for i in range(0,stringLength + 1):
    for j in range(i+1,stringLength + 1):
        subString = domainName[i:j]
        print(f"{domainName}[{i}:{j}] = {subString}")

for i in range(-stringLength-1,0):
    for j in range(i+1,0):
        subString = domainName[i:j]
        print(f"{domainName}[{i}:{j}] = {subString}")
# Out:
# Labour Management[0:1] = L
# Labour Management[0:2] = La
# Labour Management[0:3] = Lab
# Labour Management[0:4] = Labo
# Labour Management[0:5] = Labou
# Labour Management[0:6] = Labour
# Labour Management[0:7] = Labour
# Labour Management[0:8] = Labour M
# Labour Management[0:9] = Labour Ma
# Labour Management[0:10] = Labour Man
# Labour Management[0:11] = Labour Mana
# Labour Management[0:12] = Labour Manag
# Labour Management[0:13] = Labour Manage
# Labour Management[0:14] = Labour Managem
# Labour Management[0:15] = Labour Manageme
# Labour Management[0:16] = Labour Managemen
# Labour Management[0:17] = Labour Management
# Labour Management[1:2] = a
# Labour Management[1:3] = ab
# Labour Management[1:4] = abo
# Labour Management[1:5] = abou
# Labour Management[1:6] = abour
# Labour Management[1:7] = abour
# Labour Management[1:8] = abour M
# Labour Management[1:9] = abour Ma
# Labour Management[1:10] = abour Man
# Labour Management[1:11] = abour Mana
# Labour Management[1:12] = abour Manag
# Labour Management[1:13] = abour Manage
# Labour Management[1:14] = abour Managem
# Labour Management[1:15] = abour Manageme
# Labour Management[1:16] = abour Managemen
# Labour Management[1:17] = abour Management
# Labour Management[2:3] = b
# Labour Management[2:4] = bo
# Labour Management[2:5] = bou
# Labour Management[2:6] = bour
# Labour Management[2:7] = bour
# Labour Management[2:8] = bour M
# Labour Management[2:9] = bour Ma
# Labour Management[2:10] = bour Man
# Labour Management[2:11] = bour Mana
# Labour Management[2:12] = bour Manag
# Labour Management[2:13] = bour Manage
# Labour Management[2:14] = bour Managem
# Labour Management[2:15] = bour Manageme
# Labour Management[2:16] = bour Managemen
# Labour Management[2:17] = bour Management
# Labour Management[3:4] = o
# Labour Management[3:5] = ou
# Labour Management[3:6] = our
# Labour Management[3:7] = our
# Labour Management[3:8] = our M
# Labour Management[3:9] = our Ma
# Labour Management[3:10] = our Man
# Labour Management[3:11] = our Mana
# Labour Management[3:12] = our Manag
# Labour Management[3:13] = our Manage
# Labour Management[3:14] = our Managem
# Labour Management[3:15] = our Manageme
# Labour Management[3:16] = our Managemen
# Labour Management[3:17] = our Management
# Labour Management[4:5] = u
# Labour Management[4:6] = ur
# Labour Management[4:7] = ur
# Labour Management[4:8] = ur M
# Labour Management[4:9] = ur Ma
# Labour Management[4:10] = ur Man
# Labour Management[4:11] = ur Mana
# Labour Management[4:12] = ur Manag
# Labour Management[4:13] = ur Manage
# Labour Management[4:14] = ur Managem
# Labour Management[4:15] = ur Manageme
# Labour Management[4:16] = ur Managemen
# Labour Management[4:17] = ur Management
# Labour Management[5:6] = r
# Labour Management[5:7] = r
# Labour Management[5:8] = r M
# Labour Management[5:9] = r Ma
# Labour Management[5:10] = r Man
# Labour Management[5:11] = r Mana
# Labour Management[5:12] = r Manag
# Labour Management[5:13] = r Manage
# Labour Management[5:14] = r Managem
# Labour Management[5:15] = r Manageme
# Labour Management[5:16] = r Managemen
# Labour Management[5:17] = r Management
# Labour Management[6:7] =
# Labour Management[6:8] =  M
# Labour Management[6:9] =  Ma
# Labour Management[6:10] =  Man
# Labour Management[6:11] =  Mana
# Labour Management[6:12] =  Manag
# Labour Management[6:13] =  Manage
# Labour Management[6:14] =  Managem
# Labour Management[6:15] =  Manageme
# Labour Management[6:16] =  Managemen
# Labour Management[6:17] =  Management
# Labour Management[7:8] = M
# Labour Management[7:9] = Ma
# Labour Management[7:10] = Man
# Labour Management[7:11] = Mana
# Labour Management[7:12] = Manag
# Labour Management[7:13] = Manage
# Labour Management[7:14] = Managem
# Labour Management[7:15] = Manageme
# Labour Management[7:16] = Managemen
# Labour Management[7:17] = Management
# Labour Management[8:9] = a
# Labour Management[8:10] = an
# Labour Management[8:11] = ana
# Labour Management[8:12] = anag
# Labour Management[8:13] = anage
# Labour Management[8:14] = anagem
# Labour Management[8:15] = anageme
# Labour Management[8:16] = anagemen
# Labour Management[8:17] = anagement
# Labour Management[9:10] = n
# Labour Management[9:11] = na
# Labour Management[9:12] = nag
# Labour Management[9:13] = nage
# Labour Management[9:14] = nagem
# Labour Management[9:15] = nageme
# Labour Management[9:16] = nagemen
# Labour Management[9:17] = nagement
# Labour Management[10:11] = a
# Labour Management[10:12] = ag
# Labour Management[10:13] = age
# Labour Management[10:14] = agem
# Labour Management[10:15] = ageme
# Labour Management[10:16] = agemen
# Labour Management[10:17] = agement
# Labour Management[11:12] = g
# Labour Management[11:13] = ge
# Labour Management[11:14] = gem
# Labour Management[11:15] = geme
# Labour Management[11:16] = gemen
# Labour Management[11:17] = gement
# Labour Management[12:13] = e
# Labour Management[12:14] = em
# Labour Management[12:15] = eme
# Labour Management[12:16] = emen
# Labour Management[12:17] = ement
# Labour Management[13:14] = m
# Labour Management[13:15] = me
# Labour Management[13:16] = men
# Labour Management[13:17] = ment
# Labour Management[14:15] = e
# Labour Management[14:16] = en
# Labour Management[14:17] = ent
# Labour Management[15:16] = n
# Labour Management[15:17] = nt
# Labour Management[16:17] = t
# Labour Management[-18:-17] =
# Labour Management[-18:-16] = L
# Labour Management[-18:-15] = La
# Labour Management[-18:-14] = Lab
# Labour Management[-18:-13] = Labo
# Labour Management[-18:-12] = Labou
# Labour Management[-18:-11] = Labour
# Labour Management[-18:-10] = Labour
# Labour Management[-18:-9] = Labour M
# Labour Management[-18:-8] = Labour Ma
# Labour Management[-18:-7] = Labour Man
# Labour Management[-18:-6] = Labour Mana
# Labour Management[-18:-5] = Labour Manag
# Labour Management[-18:-4] = Labour Manage
# Labour Management[-18:-3] = Labour Managem
# Labour Management[-18:-2] = Labour Manageme
# Labour Management[-18:-1] = Labour Managemen
# Labour Management[-17:-16] = L
# Labour Management[-17:-15] = La
# Labour Management[-17:-14] = Lab
# Labour Management[-17:-13] = Labo
# Labour Management[-17:-12] = Labou
# Labour Management[-17:-11] = Labour
# Labour Management[-17:-10] = Labour
# Labour Management[-17:-9] = Labour M
# Labour Management[-17:-8] = Labour Ma
# Labour Management[-17:-7] = Labour Man
# Labour Management[-17:-6] = Labour Mana
# Labour Management[-17:-5] = Labour Manag
# Labour Management[-17:-4] = Labour Manage
# Labour Management[-17:-3] = Labour Managem
# Labour Management[-17:-2] = Labour Manageme
# Labour Management[-17:-1] = Labour Managemen
# Labour Management[-16:-15] = a
# Labour Management[-16:-14] = ab
# Labour Management[-16:-13] = abo
# Labour Management[-16:-12] = abou
# Labour Management[-16:-11] = abour
# Labour Management[-16:-10] = abour
# Labour Management[-16:-9] = abour M
# Labour Management[-16:-8] = abour Ma
# Labour Management[-16:-7] = abour Man
# Labour Management[-16:-6] = abour Mana
# Labour Management[-16:-5] = abour Manag
# Labour Management[-16:-4] = abour Manage
# Labour Management[-16:-3] = abour Managem
# Labour Management[-16:-2] = abour Manageme
# Labour Management[-16:-1] = abour Managemen
# Labour Management[-15:-14] = b
# Labour Management[-15:-13] = bo
# Labour Management[-15:-12] = bou
# Labour Management[-15:-11] = bour
# Labour Management[-15:-10] = bour
# Labour Management[-15:-9] = bour M
# Labour Management[-15:-8] = bour Ma
# Labour Management[-15:-7] = bour Man
# Labour Management[-15:-6] = bour Mana
# Labour Management[-15:-5] = bour Manag
# Labour Management[-15:-4] = bour Manage
# Labour Management[-15:-3] = bour Managem
# Labour Management[-15:-2] = bour Manageme
# Labour Management[-15:-1] = bour Managemen
# Labour Management[-14:-13] = o
# Labour Management[-14:-12] = ou
# Labour Management[-14:-11] = our
# Labour Management[-14:-10] = our
# Labour Management[-14:-9] = our M
# Labour Management[-14:-8] = our Ma
# Labour Management[-14:-7] = our Man
# Labour Management[-14:-6] = our Mana
# Labour Management[-14:-5] = our Manag
# Labour Management[-14:-4] = our Manage
# Labour Management[-14:-3] = our Managem
# Labour Management[-14:-2] = our Manageme
# Labour Management[-14:-1] = our Managemen
# Labour Management[-13:-12] = u
# Labour Management[-13:-11] = ur
# Labour Management[-13:-10] = ur
# Labour Management[-13:-9] = ur M
# Labour Management[-13:-8] = ur Ma
# Labour Management[-13:-7] = ur Man
# Labour Management[-13:-6] = ur Mana
# Labour Management[-13:-5] = ur Manag
# Labour Management[-13:-4] = ur Manage
# Labour Management[-13:-3] = ur Managem
# Labour Management[-13:-2] = ur Manageme
# Labour Management[-13:-1] = ur Managemen
# Labour Management[-12:-11] = r
# Labour Management[-12:-10] = r
# Labour Management[-12:-9] = r M
# Labour Management[-12:-8] = r Ma
# Labour Management[-12:-7] = r Man
# Labour Management[-12:-6] = r Mana
# Labour Management[-12:-5] = r Manag
# Labour Management[-12:-4] = r Manage
# Labour Management[-12:-3] = r Managem
# Labour Management[-12:-2] = r Manageme
# Labour Management[-12:-1] = r Managemen
# Labour Management[-11:-10] =
# Labour Management[-11:-9] =  M
# Labour Management[-11:-8] =  Ma
# Labour Management[-11:-7] =  Man
# Labour Management[-11:-6] =  Mana
# Labour Management[-11:-5] =  Manag
# Labour Management[-11:-4] =  Manage
# Labour Management[-11:-3] =  Managem
# Labour Management[-11:-2] =  Manageme
# Labour Management[-11:-1] =  Managemen
# Labour Management[-10:-9] = M
# Labour Management[-10:-8] = Ma
# Labour Management[-10:-7] = Man
# Labour Management[-10:-6] = Mana
# Labour Management[-10:-5] = Manag
# Labour Management[-10:-4] = Manage
# Labour Management[-10:-3] = Managem
# Labour Management[-10:-2] = Manageme
# Labour Management[-10:-1] = Managemen
# Labour Management[-9:-8] = a
# Labour Management[-9:-7] = an
# Labour Management[-9:-6] = ana
# Labour Management[-9:-5] = anag
# Labour Management[-9:-4] = anage
# Labour Management[-9:-3] = anagem
# Labour Management[-9:-2] = anageme
# Labour Management[-9:-1] = anagemen
# Labour Management[-8:-7] = n
# Labour Management[-8:-6] = na
# Labour Management[-8:-5] = nag
# Labour Management[-8:-4] = nage
# Labour Management[-8:-3] = nagem
# Labour Management[-8:-2] = nageme
# Labour Management[-8:-1] = nagemen
# Labour Management[-7:-6] = a
# Labour Management[-7:-5] = ag
# Labour Management[-7:-4] = age
# Labour Management[-7:-3] = agem
# Labour Management[-7:-2] = ageme
# Labour Management[-7:-1] = agemen
# Labour Management[-6:-5] = g
# Labour Management[-6:-4] = ge
# Labour Management[-6:-3] = gem
# Labour Management[-6:-2] = geme
# Labour Management[-6:-1] = gemen
# Labour Management[-5:-4] = e
# Labour Management[-5:-3] = em
# Labour Management[-5:-2] = eme
# Labour Management[-5:-1] = emen
# Labour Management[-4:-3] = m
# Labour Management[-4:-2] = me
# Labour Management[-4:-1] = men
# Labour Management[-3:-2] = e
# Labour Management[-3:-1] = en
# Labour Management[-2:-1] = n
